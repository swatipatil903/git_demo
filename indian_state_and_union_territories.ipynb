# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://en.wikipedia.org/wiki/States_and_union_territories_of_India"
page=requests.get(url)
soup=BeautifulSoup(page.content,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-enabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>States and union territories of India - Wikipedia</title>
# ...

# %%
tables=soup.find_all(class_="wikitable sortable plainrowheaders")
len(tables)
# Out:
# 2

# %%
states=tables[0]
states
# Out:
# <table class="wikitable sortable plainrowheaders" style="text-align: center;">
# <caption>
# </caption>
# <tbody><tr>
# <th scope="col">State
# </th>
# <th scope="col"><a href="/wiki/ISO_3166-2:IN" title="ISO 3166-2:IN">ISO</a>
# </th>
# <th scope="col"><a href="/wiki/Vehicle_registration_plates_of_India" title="Vehicle registration plates of India">Vehicle<br/>code</a>
# </th>
# <th scope="col"><a class="mw-redirect" href="/wiki/Zonal_Council" title="Zonal Council">Zone</a>
# </th>
# <th scope="col">Capital
# </th>
# <th scope="col">Largest city
# </th>
# <th data-sort-type="date" scope="col">Statehood
# </th>
# <th scope="col">Population<br/>(2011)<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (December 2020)">citation needed</span></a></i>]</sup>
# </th>
# ...

# %%
heads=states.find_all("th")[:11]
heads
# Out:
# [<th scope="col">State
#  </th>,
#  <th scope="col"><a href="/wiki/ISO_3166-2:IN" title="ISO 3166-2:IN">ISO</a>
#  </th>,
#  <th scope="col"><a href="/wiki/Vehicle_registration_plates_of_India" title="Vehicle registration plates of India">Vehicle<br/>code</a>
#  </th>,
#  <th scope="col"><a class="mw-redirect" href="/wiki/Zonal_Council" title="Zonal Council">Zone</a>
#  </th>,
#  <th scope="col">Capital
#  </th>,
#  <th scope="col">Largest city
#  </th>,
#  <th data-sort-type="date" scope="col">Statehood
#  </th>,
#  <th scope="col">Population<br/>(2011)<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (December 2020)">citation needed</span></a></i>]</sup>
#  </th>,
# ...

# %%
head=states.find_all('th')[:11]
heads
# Out:
# [<th scope="col">State
#  </th>,
#  <th scope="col"><a href="/wiki/ISO_3166-2:IN" title="ISO 3166-2:IN">ISO</a>
#  </th>,
#  <th scope="col"><a href="/wiki/Vehicle_registration_plates_of_India" title="Vehicle registration plates of India">Vehicle<br/>code</a>
#  </th>,
#  <th scope="col"><a class="mw-redirect" href="/wiki/Zonal_Council" title="Zonal Council">Zone</a>
#  </th>,
#  <th scope="col">Capital
#  </th>,
#  <th scope="col">Largest city
#  </th>,
#  <th data-sort-type="date" scope="col">Statehood
#  </th>,
#  <th scope="col">Population<br/>(2011)<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (December 2020)">citation needed</span></a></i>]</sup>
#  </th>,
# ...

# %%
t=[]
for p in states.find_all("th")[:11]:
    t.append(p.get_text().strip())
t
# Out:
# ['State',
#  'ISO',
#  'Vehiclecode',
#  'Zone',
#  'Capital',
#  'Largest city',
#  'Statehood',
#  'Population(2011)[citation needed]',
#  'Area(km2)',
#  'Officiallanguages[39]',
#  'Additional officiallanguages[39]']

# %%
col_heads=[p.get_text().strip()for p in states.find_all('th')[:11]]
col_heads
# Out:
# ['State',
#  'ISO',
#  'Vehiclecode',
#  'Zone',
#  'Capital',
#  'Largest city',
#  'Statehood',
#  'Population(2011)[citation needed]',
#  'Area(km2)',
#  'Officiallanguages[39]',
#  'Additional officiallanguages[39]']

# %%
table_data=states.find_all('tr')[1:]
table_data
# Out:
# [<tr>
#  <th scope="row"><a href="/wiki/Andhra_Pradesh" title="Andhra Pradesh">Andhra Pradesh</a>
#  </th>
#  <td>IN-AP
#  </td>
#  <td>AP
#  </td>
#  <td><a href="/wiki/Southern_Zonal_Council" title="Southern Zonal Council">Southern</a>
#  </td>
#  <td><a href="/wiki/Amaravati" title="Amaravati">Amaravati</a>
#  </td>
#  <td><a href="/wiki/Visakhapatnam" title="Visakhapatnam">Visakhapatnam</a>
#  </td>
#  <td>1 November 1956
#  </td>
#  <td align="right">49,506,799
#  </td>
#  <td align="right">162,975
#  </td>
#  <td><a href="/wiki/Telugu_language" title="Telugu language">Telugu</a>
#  </td>
#  <td><a href="/wiki/Urdu" title="Urdu">Urdu</a><sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[40]</a></sup>
#  </td></tr>,
#  <tr>
#  <th scope="row"><a href="/wiki/Arunachal_Pradesh" title="Arunachal Pradesh">Arunachal Pradesh</a>
#  </th>
#  <td>IN-AR
#  </td>
#  <td>AR
#  </td>
#  <td><a href="/wiki/North_Eastern_Council" title="North Eastern Council">North-Eastern</a>
# ...

# %%
col_heads=[p.get_text().strip() for p in states.find_all('th')[:11]]
col_heads
# Out:
# ['State',
#  'ISO',
#  'Vehiclecode',
#  'Zone',
#  'Capital',
#  'Largest city',
#  'Statehood',
#  'Population(2011)[citation needed]',
#  'Area(km2)',
#  'Officiallanguages[39]',
#  'Additional officiallanguages[39]']

# %%
state=[p.get_text().strip() for p in states.find_all('th')[11:] ]
state
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
table_data=states.find_all('tr')[1:]
table_data
# Out:
# [<tr>
#  <th scope="row"><a href="/wiki/Andhra_Pradesh" title="Andhra Pradesh">Andhra Pradesh</a>
#  </th>
#  <td>IN-AP
#  </td>
#  <td>AP
#  </td>
#  <td><a href="/wiki/Southern_Zonal_Council" title="Southern Zonal Council">Southern</a>
#  </td>
#  <td><a href="/wiki/Amaravati" title="Amaravati">Amaravati</a>
#  </td>
#  <td><a href="/wiki/Visakhapatnam" title="Visakhapatnam">Visakhapatnam</a>
#  </td>
#  <td>1 November 1956
#  </td>
#  <td align="right">49,506,799
#  </td>
#  <td align="right">162,975
#  </td>
#  <td><a href="/wiki/Telugu_language" title="Telugu language">Telugu</a>
#  </td>
#  <td><a href="/wiki/Urdu" title="Urdu">Urdu</a><sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[40]</a></sup>
#  </td></tr>,
#  <tr>
#  <th scope="row"><a href="/wiki/Arunachal_Pradesh" title="Arunachal Pradesh">Arunachal Pradesh</a>
#  </th>
#  <td>IN-AR
#  </td>
#  <td>AR
#  </td>
#  <td><a href="/wiki/North_Eastern_Council" title="North Eastern Council">North-Eastern</a>
# ...

# %%
row=[d.get_text().strip() for d in table_data[0].find_all('td')]
row
# Out:
# ['IN-AP',
#  'AP',
#  'Southern',
#  'Amaravati',
#  'Visakhapatnam',
#  '1 November 1956',
#  '49,506,799',
#  '162,975',
#  'Telugu',
#  'Urdu[40]']

# %%
len(table_data)
# Out:
# 28

# %%
table_rows=[[d.get_text().strip() for d in table_data[0].find_all('td')] for i in range(len(table_data))]
table_rows
# Out:
# [['IN-AP',
#   'AP',
#   'Southern',
#   'Amaravati',
#   'Visakhapatnam',
#   '1 November 1956',
#   '49,506,799',
#   '162,975',
#   'Telugu',
#   'Urdu[40]'],
#  ['IN-AP',
#   'AP',
#   'Southern',
#   'Amaravati',
#   'Visakhapatnam',
#   '1 November 1956',
#   '49,506,799',
#   '162,975',
#   'Telugu',
#   'Urdu[40]'],
#  ['IN-AP',
#   'AP',
#   'Southern',
#   'Amaravati',
#   'Visakhapatnam',
#   '1 November 1956',
#   '49,506,799',
#   '162,975',
#   'Telugu',
#   'Urdu[40]'],
#  ['IN-AP',
#   'AP',
#   'Southern',
#   'Amaravati',
#   'Visakhapatnam',
#   '1 November 1956',
#   '49,506,799',
#   '162,975',
#   'Telugu',
#   'Urdu[40]'],
#  ['IN-AP',
#   'AP',
#   'Southern',
#   'Amaravati',
#   'Visakhapatnam',
#   '1 November 1956',
#   '49,506,799',
#   '162,975',
#   'Telugu',
#   'Urdu[40]'],
#  ['IN-AP',
#   'AP',
#   'Southern',
#   'Amaravati',
#   'Visakhapatnam',
#   '1 November 1956',
#   '49,506,799',
#   '162,975',
#   'Telugu',
#   'Urdu[40]'],
#  ['IN-AP',
# ...

# %%
for i in table_rows:
    print(len(i))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
for i in table_rows:
    print(i)
    break
# Out:
# ['IN-AP', 'AP', 'Southern', 'Amaravati', 'Visakhapatnam', '1 November 1956', '49,506,799', '162,975', 'Telugu', 'Urdu[40]']

# %%
d={k:[]for k in col_heads}
d
# Out:
# {'State': [],
#  'ISO': [],
#  'Vehiclecode': [],
#  'Zone': [],
#  'Capital': [],
#  'Largest city': [],
#  'Statehood': [],
#  'Population(2011)[citation needed]': [],
#  'Area(km2)': [],
#  'Officiallanguages[39]': [],
#  'Additional officiallanguages[39]': []}

# %%
for p in table_rows:
    if len(p)==10:
        d['ISO'].append(p[0])
        d['Vehiclecode'].append(p[1])
        d['Zone'].append(p[2])
        d['Capital'].append(p[3])
        d['Largest city'].append(p[4])
        d['Statehood'].append(p[5])
        d['Population(2011)[citation needed]'].append(p[6])
        d['Area(km2)'].append(p[7])
        d['Officiallanguages[39]'].append(p[8])
        d['Additional officiallanguages[39]'].append(p[9])
    else:
        d['ISO'].append(p[0])
        d['Vehiclecode'].append(p[1])
        d['Zone'].append(p[2])
        d['Capital'].append(p[3])
        d['Largest city'].append(p[3])
        d['Statehood'].append(p[4])
        d['Population(2011)[citation needed]'].append(p[5])
        d['Area(km2)'].append(p[6])
        d['Officiallanguages[39]'].append(p[7])
        d['Additional officiallanguages[39]'].append(p[8])

d
# Out:
# {'State': ['Andhra Pradesh',
#   'Arunachal Pradesh',
#   'Assam',
#   'Bihar',
#   'Chhattisgarh',
#   'Goa',
#   'Gujarat',
#   'Haryana',
#   'Himachal Pradesh',
#   'Jharkhand',
#   'Karnataka',
#   'Kerala',
#   'Madhya Pradesh',
#   'Maharashtra',
#   'Manipur',
#   'Meghalaya',
#   'Mizoram',
#   'Nagaland',
#   'Odisha',
#   'Punjab',
#   'Rajasthan',
#   'Sikkim',
#   'Tamil Nadu',
#   'Telangana',
#   'Tripura',
#   'Uttar Pradesh',
#   'Uttarakhand',
#   'West Bengal'],
#  'ISO': ['IN-AP',
#   'IN-AR',
#   'IN-AS',
#   'IN-BR',
#   'IN-CT',
#   'IN-GA',
#   'IN-GJ',
#   'IN-HR',
#   'IN-HP',
#   'IN-JH',
#   'IN-KA',
#   'IN-KL',
#   'IN-MP',
#   'IN-MH',
#   'IN-MN',
#   'IN-ML',
#   'IN-MZ',
#   'IN-NL',
#   'IN-OR',
#   'IN-PB',
#   'IN-RJ',
#   'IN-SK',
#   'IN-TN',
#   'IN-TG',
#   'IN-TR',
#   'IN-UP',
#   'IN-UT',
#   'IN-WB'],
#  'Vehiclecode': ['AP',
#   'AR',
#   'AS',
#   'BR',
#   'CG',
#   'GA',
#   'GJ',
#   'HR',
#   'HP',
#   'JH',
#   'KA',
#   'KL',
# ...

# %%
d['State']=state
d
# Out:
# {'State': ['Andhra Pradesh',
#   'Arunachal Pradesh',
#   'Assam',
#   'Bihar',
#   'Chhattisgarh',
#   'Goa',
#   'Gujarat',
#   'Haryana',
#   'Himachal Pradesh',
#   'Jharkhand',
#   'Karnataka',
#   'Kerala',
#   'Madhya Pradesh',
#   'Maharashtra',
#   'Manipur',
#   'Meghalaya',
#   'Mizoram',
#   'Nagaland',
#   'Odisha',
#   'Punjab',
#   'Rajasthan',
#   'Sikkim',
#   'Tamil Nadu',
#   'Telangana',
#   'Tripura',
#   'Uttar Pradesh',
#   'Uttarakhand',
#   'West Bengal'],
#  'ISO': [],
#  'Vehiclecode': [],
#  'Zone': [],
#  'Capital': [],
#  'Largest city': [],
#  'Statehood': [],
#  'Population(2011)[citation needed]': [],
#  'Area(km2)': [],
#  'Officiallanguages[39]': [],
#  'Additional officiallanguages[39]': []}

# %%
df_state=pd.DataFrame(d)
df_state
# Out:
#                 State    ISO Vehiclecode           Zone  \
# 0      Andhra Pradesh  IN-AP          AP       Southern
# 1   Arunachal Pradesh  IN-AR          AR  North-Eastern
# 2               Assam  IN-AS          AS  North-Eastern
# 3               Bihar  IN-BR          BR        Eastern
# 4        Chhattisgarh  IN-CT          CG        Central
# 5                 Goa  IN-GA          GA        Western
# 6             Gujarat  IN-GJ          GJ        Western
# 7             Haryana  IN-HR          HR       Northern
# 8    Himachal Pradesh  IN-HP          HP       Northern
# 9           Jharkhand  IN-JH          JH        Eastern
# 10          Karnataka  IN-KA          KA       Southern
# 11             Kerala  IN-KL          KL       Southern
# 12     Madhya Pradesh  IN-MP          MP        Central
# 13        Maharashtra  IN-MH          MH        Western
# 14            Manipur  IN-MN          MN  North-Eastern
# 15          Meghalaya  IN-ML          ML  North-Eastern
# ...

# %%
unions=tables[1]
unions
# Out:
# <table class="wikitable sortable plainrowheaders" style="text-align: center; font-size: 90%;">
# <tbody><tr>
# <th scope="col" style="width:8%;">Union territory
# </th>
# <th scope="col" style="width:1%;"><a href="/wiki/ISO_3166-2:IN" title="ISO 3166-2:IN">ISO 3166-2:IN</a>
# </th>
# <th scope="col" style="width:1%;"><a href="/wiki/Vehicle_registration_plates_of_India" title="Vehicle registration plates of India">Vehicle<br/>code</a>
# </th>
# <th scope="col" style="width:1%;"><a class="mw-redirect" href="/wiki/Zonal_Council" title="Zonal Council">Zone</a>
# </th>
# <th scope="col" style="width:1%;">Capital
# </th>
# <th scope="col" style="width:1%;">Largest city
# </th>
# <th scope="col" style="width:1%;">UT established
# </th>
# <th scope="col" style="width:1%;">Population
# </th>
# <th scope="col" style="width:1%;"><a href="/wiki/List_of_states_and_union_territories_of_India_by_area" title="List of states and union territories of India by area">Area</a><br/>(km<sup>2</sup>)
# ...

# %%
un_col_heads=[p.get_text().strip() for p in unions.find_all('th')[:11] ]
un_col_heads
# Out:
# ['Union territory',
#  'ISO 3166-2:IN',
#  'Vehiclecode',
#  'Zone',
#  'Capital',
#  'Largest city',
#  'UT established',
#  'Population',
#  'Area(km2)',
#  'Officiallanguages',
#  'Additional officiallanguages']

# %%
un_col=[p.get_text().strip() for p in unions.find_all('th')[11:] ]
un_col
# Out:
# ['Andaman and Nicobar Islands',
#  'Chandigarh',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Delhi',
#  'Jammu and Kashmir',
#  'Ladakh',
#  'Lakshadweep',
#  'Puducherry']

# %%
table_data=unions.find_all('tr')[1:]
table_data
# Out:
# [<tr>
#  <th scope="row"><a href="/wiki/Andaman_and_Nicobar_Islands" title="Andaman and Nicobar Islands">Andaman and Nicobar Islands</a>
#  </th>
#  <td>IN-AN
#  </td>
#  <td>AN
#  </td>
#  <td>Southern
#  </td>
#  <td colspan="2"><a href="/wiki/Port_Blair" title="Port Blair">Port Blair</a>
#  </td>
#  <td>1 November 1956
#  </td>
#  <td align="right">380,581
#  </td>
#  <td align="right">8,249
#  </td>
#  <td><a href="/wiki/Hindi" title="Hindi">Hindi</a>
#  </td>
#  <td>English
#  </td></tr>,
#  <tr>
#  <th scope="row"><a href="/wiki/Chandigarh" title="Chandigarh">Chandigarh</a>
#  </th>
#  <td>IN-CH
#  </td>
#  <td>CH
#  </td>
#  <td>Northern
#  </td>
#  <td colspan="2"><a href="/wiki/Chandigarh" title="Chandigarh">Chandigarh</a>
#  </td>
#  <td>1 November 1966
#  </td>
#  <td align="right">1,055,450
#  </td>
#  <td align="right">114
#  </td>
#  <td>English
#  </td>
#  <td><a href="/wiki/Punjabi_language" title="Punjabi language">Punjabi</a>
#  </td></tr>,
#  <tr>
# ...

# %%
table_rows=[[d.get_text().strip() for d in table_data[i].find_all('td')] for i in range(len(table_data))]
table_rows
# Out:
# [['IN-AN',
#   'AN',
#   'Southern',
#   'Port Blair',
#   '1 November 1956',
#   '380,581',
#   '8,249',
#   'Hindi',
#   'English'],
#  ['IN-CH',
#   'CH',
#   'Northern',
#   'Chandigarh',
#   '1 November 1966',
#   '1,055,450',
#   '114',
#   'English',
#   'Punjabi'],
#  ['IN-DH',
#   'DD',
#   'Western',
#   'Daman',
#   '26 January 2020',
#   '586,956',
#   '603',
#   'Gujarati, Marathi, English',
#   '—'],
#  ['IN-DL',
#   'DL',
#   'Northern',
#   'New Delhi',
#   'Delhi',
#   '1 November 1956',
#   '16,787,941',
#   '1,490',
#   'Hindi, English',
#   'Punjabi[58]'],
#  ['IN-JK',
#   'JK',
#   'Northern',
#   'Srinagar (Summer)[59][60]Jammu (Winter)[60][61]',
#   'Srinagar',
#   '31 October 2019',
#   '12,258,433',
#   '42,241',
#   'Urdu, English',
#   'Kashmiri, Dogri, Hindi'],
#  ['IN-LA',
#   'LA',
#   'Northern',
#   'Leh (Summer)Kargil (Winter)[62]',
#   'Leh',
#   '31 October 2019',
#   '290,492',
#   '59,146',
#   'Hindi and English',
#   ''],
#  ['IN-LD',
#   'LD',
# ...

# %%
d1={k:[] for k in un_col_heads}
d1
# Out:
# {'Union territory': [],
#  'ISO 3166-2:IN': [],
#  'Vehiclecode': [],
#  'Zone': [],
#  'Capital': [],
#  'Largest city': [],
#  'UT established': [],
#  'Population': [],
#  'Area(km2)': [],
#  'Officiallanguages': [],
#  'Additional officiallanguages': []}

# %%
for p in table_rows:
    if len(p)==10:
        d1['ISO 3166-2:IN'].append(p[0])
        d1['Vehiclecode'].append(p[1])
        d1['Zone'].append(p[2])
        d1['Capital'].append(p[3])
        d1['Largest city'].append(p[4])
        d1['UT established'].append(p[5])
        d1['Population'].append(p[6])
        d1['Area(km2)'].append(p[7])
        d1['Officiallanguages'].append(p[8])
        d1['Additional officiallanguages'].append(p[9])
    else:
        d1['ISO 3166-2:IN'].append(p[0])
        d1['Vehiclecode'].append(p[1])
        d1['Zone'].append(p[2])
        d1['Capital'].append(p[3])
        d1['Largest city'].append(p[3])
        d1['UT established'].append(p[4])
        d1['Population'].append(p[5])
        d1['Area(km2)'].append(p[6])
        d1['Officiallanguages'].append(p[7])
        d1['Additional officiallanguages'].append(p[8])

d1
# Out:
# {'Union territory': [],
#  'ISO 3166-2:IN': ['IN-AN',
#   'IN-CH',
#   'IN-DH',
#   'IN-DL',
#   'IN-JK',
#   'IN-LA',
#   'IN-LD',
#   'IN-PY'],
#  'Vehiclecode': ['AN', 'CH', 'DD', 'DL', 'JK', 'LA', 'LD', 'PY'],
#  'Zone': ['Southern',
#   'Northern',
#   'Western',
#   'Northern',
#   'Northern',
#   'Northern',
#   'Southern',
#   'Southern'],
#  'Capital': ['Port Blair',
#   'Chandigarh',
#   'Daman',
#   'New Delhi',
#   'Srinagar (Summer)[59][60]Jammu (Winter)[60][61]',
#   'Leh (Summer)Kargil (Winter)[62]',
#   'Kavaratti',
#   'Puducherry'],
#  'Largest city': ['Port Blair',
#   'Chandigarh',
#   'Daman',
#   'Delhi',
#   'Srinagar',
#   'Leh',
#   'Kavaratti',
#   'Puducherry'],
#  'UT established': ['1 November 1956',
#   '1 November 1966',
#   '26 January 2020',
#   '1 November 1956',
#   '31 October 2019',
#   '31 October 2019',
#   '1 November 1956',
#   '16 August 1962'],
#  'Population': ['380,581',
#   '1,055,450',
#   '586,956',
#   '16,787,941',
#   '12,258,433',
# ...

# %%
d1['Union territory']=un_col
d1
# Out:
# {'Union territory': ['Andaman and Nicobar Islands',
#   'Chandigarh',
#   'Dadra and Nagar Haveli and Daman and Diu',
#   'Delhi',
#   'Jammu and Kashmir',
#   'Ladakh',
#   'Lakshadweep',
#   'Puducherry'],
#  'ISO 3166-2:IN': ['IN-AN',
#   'IN-CH',
#   'IN-DH',
#   'IN-DL',
#   'IN-JK',
#   'IN-LA',
#   'IN-LD',
#   'IN-PY'],
#  'Vehiclecode': ['AN', 'CH', 'DD', 'DL', 'JK', 'LA', 'LD', 'PY'],
#  'Zone': ['Southern',
#   'Northern',
#   'Western',
#   'Northern',
#   'Northern',
#   'Northern',
#   'Southern',
#   'Southern'],
#  'Capital': ['Port Blair',
#   'Chandigarh',
#   'Daman',
#   'New Delhi',
#   'Srinagar (Summer)[59][60]Jammu (Winter)[60][61]',
#   'Leh (Summer)Kargil (Winter)[62]',
#   'Kavaratti',
#   'Puducherry'],
#  'Largest city': ['Port Blair',
#   'Chandigarh',
#   'Daman',
#   'Delhi',
#   'Srinagar',
#   'Leh',
#   'Kavaratti',
#   'Puducherry'],
#  'UT established': ['1 November 1956',
#   '1 November 1966',
#   '26 January 2020',
#   '1 November 1956',
# ...

# %%
df2=pd.DataFrame(d1)
df2
# Out:
#                             Union territory ISO 3166-2:IN Vehiclecode  \
# 0               Andaman and Nicobar Islands         IN-AN          AN
# 1                                Chandigarh         IN-CH          CH
# 2  Dadra and Nagar Haveli and Daman and Diu         IN-DH          DD
# 3                                     Delhi         IN-DL          DL
# 4                         Jammu and Kashmir         IN-JK          JK
# 5                                    Ladakh         IN-LA          LA
# 6                               Lakshadweep         IN-LD          LD
# 7                                Puducherry         IN-PY          PY
#
#        Zone                                          Capital Largest city  \
# 0  Southern                                       Port Blair   Port Blair
# 1  Northern                                       Chandigarh   Chandigarh
# 2   Western                                            Daman        Daman
# ...

# %%
df_state.to_csv('India_states.csv', index=False)
df2.to_csv('India_union_ter.csv', index=False)
